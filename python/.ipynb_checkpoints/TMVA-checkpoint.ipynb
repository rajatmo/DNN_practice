# %%
#check if JupyROOT works 
import ROOT
# Out:
# Welcome to JupyROOT 6.15/01

# %%
import glob
import itertools as it
import numpy as np
import math , array 
import random
from subprocess import call
from os.path import isfile
from numpy.lib.recfunctions import append_fields
from itertools import product

import keras
import keras.optimizers
from keras.optimizers import SGD
from keras.models import Sequential
from keras.utils import to_categorical
from keras.layers import Dense, Activation
from keras.regularizers import l2

from ROOT import TCanvas, TMVA, TFile, TTree, TCut
# Out:
# Using TensorFlow backend.

# %%
bkg='TTV'
path='../root/2017/forBDTtraining/'
frac=0.5

# %%
varlist=[
    #'taupt',
    #'avg_dr_jet',
    'njet',
    'tau_eta',
    #'dr_leps',
    #'mindr_tau_jet',
    #'mindr_lep1_jet',
    #'dr_lep1_tau_jet',
    'mTauTauVis',
    'mT_lep2',
    #'mindr_lep2_jet',
    #'dr_lep2_tau_ss',
    #'dr_lep1_tau_os',
    #'mbb_loose',
    #'lep2_conePt',
    #'nBJetLoose',
    #'min_lep_eta',
    'mT_lep1',
    'ptmiss',
    #'max_lep_eta',
    #'lep1_conePt',
    #'drbb_loose'
]

# %%
###============================path to root files

forBDTtraining="forBDTtraining"
channel='2los_1tau'
rootfilepath = path+"*/*.root"
list = glob.glob(rootfilepath)
#print list

# %%
#========convert list of filenames to list of tfile objects

root_files=[]
for x in range(0,len(list)):
    try: root_files.append(TFile.Open(list[x]))
    except: continue
#root_files
# Out:
# [<ROOT.TFile object ("../root/2017/forBDTtraining/ttHToNonbb_M125_powheg/ttHToNonbb_M125_powheg_forBDTtraining_central_1.root") at 0x7f74ad98ebe0>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/ttHToNonbb_M125_powheg/ttHToNonbb_M125_powheg_forBDTtraining_central_2.root") at 0x7f7334fce4d0>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/ttHToNonbb_M125_powheg/ttHToNonbb_M125_powheg_forBDTtraining_central_3.root") at 0x7f7339ce84c0>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/ttHToNonbb_M125_powheg/ttHToNonbb_M125_powheg_forBDTtraining_central_4.root") at 0x7f7339ce6fc0>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/ttHToNonbb_M125_powheg/ttHToNonbb_M125_powheg_forBDTtraining_central_5.root") at 0x7f733a9ef9c0>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/ttHToNonbb_M125_powheg/ttHToNonbb_M125_powheg_forBDTtraining_central_6.root") at 0x7f733a9f0060>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTTo2L2Nu/TTTo2L2Nu_forBDTtraining_central_1.root") at 0x7f733a9efd10>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTTo2L2Nu/TTTo2L2Nu_forBDTtraining_central_2.root") at 0x7f74a364dbc0>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTTo2L2Nu/TTTo2L2Nu_forBDTtraining_central_3.root") at 0x7f7502698800>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTTo2L2Nu/TTTo2L2Nu_forBDTtraining_central_4.root") at 0x7f75029207a0>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTTo2L2Nu/TTTo2L2Nu_forBDTtraining_central_5.root") at 0x7f73408319b0>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTTo2L2Nu/TTTo2L2Nu_forBDTtraining_central_6.root") at 0x7f75023b4110>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTTo2L2Nu_PSweights/TTTo2L2Nu_PSweights_forBDTtraining_central_1.root") at 0x7f750226e4a0>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTTo2L2Nu_PSweights/TTTo2L2Nu_PSweights_forBDTtraining_central_10.root") at 0x7f74ad2d8cd0>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTTo2L2Nu_PSweights/TTTo2L2Nu_PSweights_forBDTtraining_central_11.root") at 0x7f733e848af0>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTTo2L2Nu_PSweights/TTTo2L2Nu_PSweights_forBDTtraining_central_12.root") at 0x7f7433a4a1a0>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTTo2L2Nu_PSweights/TTTo2L2Nu_PSweights_forBDTtraining_central_13.root") at 0x7f74397706a0>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTTo2L2Nu_PSweights/TTTo2L2Nu_PSweights_forBDTtraining_central_14.root") at 0x7f744ca3a7f0>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTTo2L2Nu_PSweights/TTTo2L2Nu_PSweights_forBDTtraining_central_15.root") at 0x7f7448ae4940>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTTo2L2Nu_PSweights/TTTo2L2Nu_PSweights_forBDTtraining_central_16.root") at 0x7f7448abb2e0>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTTo2L2Nu_PSweights/TTTo2L2Nu_PSweights_forBDTtraining_central_17.root") at 0x7f744317f560>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTTo2L2Nu_PSweights/TTTo2L2Nu_PSweights_forBDTtraining_central_18.root") at 0x7f749821e250>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTTo2L2Nu_PSweights/TTTo2L2Nu_PSweights_forBDTtraining_central_19.root") at 0x7f7435b0f110>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTTo2L2Nu_PSweights/TTTo2L2Nu_PSweights_forBDTtraining_central_2.root") at 0x7f72d5bab280>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTTo2L2Nu_PSweights/TTTo2L2Nu_PSweights_forBDTtraining_central_20.root") at 0x7f72eac2d240>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTTo2L2Nu_PSweights/TTTo2L2Nu_PSweights_forBDTtraining_central_21.root") at 0x7f72e6e24b20>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTTo2L2Nu_PSweights/TTTo2L2Nu_PSweights_forBDTtraining_central_22.root") at 0x7f72e11bf340>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTTo2L2Nu_PSweights/TTTo2L2Nu_PSweights_forBDTtraining_central_23.root") at 0x7f72df4bb640>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTTo2L2Nu_PSweights/TTTo2L2Nu_PSweights_forBDTtraining_central_24.root") at 0x7f72dd70c1f0>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTTo2L2Nu_PSweights/TTTo2L2Nu_PSweights_forBDTtraining_central_25.root") at 0x7f72d998f840>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTTo2L2Nu_PSweights/TTTo2L2Nu_PSweights_forBDTtraining_central_26.root") at 0x7f72d978bdf0>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTTo2L2Nu_PSweights/TTTo2L2Nu_PSweights_forBDTtraining_central_27.root") at 0x7f7502ddd8a0>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTTo2L2Nu_PSweights/TTTo2L2Nu_PSweights_forBDTtraining_central_28.root") at 0x7f71f78ceab0>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTTo2L2Nu_PSweights/TTTo2L2Nu_PSweights_forBDTtraining_central_29.root") at 0x7f7392dcf350>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTTo2L2Nu_PSweights/TTTo2L2Nu_PSweights_forBDTtraining_central_3.root") at 0x7f73e69899d0>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTTo2L2Nu_PSweights/TTTo2L2Nu_PSweights_forBDTtraining_central_30.root") at 0x7f743b44c8d0>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTTo2L2Nu_PSweights/TTTo2L2Nu_PSweights_forBDTtraining_central_31.root") at 0x7f74a6bcf000>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTTo2L2Nu_PSweights/TTTo2L2Nu_PSweights_forBDTtraining_central_32.root") at 0x7f728aa0ebf0>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTTo2L2Nu_PSweights/TTTo2L2Nu_PSweights_forBDTtraining_central_33.root") at 0x7f72d01cfbf0>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTTo2L2Nu_PSweights/TTTo2L2Nu_PSweights_forBDTtraining_central_34.root") at 0x7f73e6a8e780>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTTo2L2Nu_PSweights/TTTo2L2Nu_PSweights_forBDTtraining_central_35.root") at 0x7f74117cfc20>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTTo2L2Nu_PSweights/TTTo2L2Nu_PSweights_forBDTtraining_central_36.root") at 0x7f742ffcf6e0>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTTo2L2Nu_PSweights/TTTo2L2Nu_PSweights_forBDTtraining_central_37.root") at 0x7f750039ce80>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTTo2L2Nu_PSweights/TTTo2L2Nu_PSweights_forBDTtraining_central_38.root") at 0x7f723e54f4b0>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTTo2L2Nu_PSweights/TTTo2L2Nu_PSweights_forBDTtraining_central_39.root") at 0x7f72d3e4e000>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTTo2L2Nu_PSweights/TTTo2L2Nu_PSweights_forBDTtraining_central_4.root") at 0x7f71e4593870>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTTo2L2Nu_PSweights/TTTo2L2Nu_PSweights_forBDTtraining_central_40.root") at 0x7f73a584f380>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTTo2L2Nu_PSweights/TTTo2L2Nu_PSweights_forBDTtraining_central_41.root") at 0x7f724f10fc50>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTTo2L2Nu_PSweights/TTTo2L2Nu_PSweights_forBDTtraining_central_42.root") at 0x7f74c8f522a0>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTTo2L2Nu_PSweights/TTTo2L2Nu_PSweights_forBDTtraining_central_43.root") at 0x7f73d400cc10>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTTo2L2Nu_PSweights/TTTo2L2Nu_PSweights_forBDTtraining_central
,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTToSemiLeptonic_PSweights/TTToSemiLeptonic_PSweights_forBDTtraining_central_50.root") at 0x7f73fcf8c570>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTToSemiLeptonic_PSweights/TTToSemiLeptonic_PSweights_forBDTtraining_central_51.root") at 0x7f721cccf230>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTToSemiLeptonic_PSweights/TTToSemiLeptonic_PSweights_forBDTtraining_central_52.root") at 0x7f74aedd7430>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTToSemiLeptonic_PSweights/TTToSemiLeptonic_PSweights_forBDTtraining_central_53.root") at 0x7f74ac181940>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTToSemiLeptonic_PSweights/TTToSemiLeptonic_PSweights_forBDTtraining_central_54.root") at 0x7f7502c3d9b0>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTToSemiLeptonic_PSweights/TTToSemiLeptonic_PSweights_forBDTtraining_central_55.root") at 0x7f74a3c815d0>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTToSemiLeptonic_PSweights/TTToSemiLeptonic_PSweights_forBDTtraining_central_56.root") at 0x7f74a277a2d0>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTToSemiLeptonic_PSweights/TTToSemiLeptonic_PSweights_forBDTtraining_central_57.root") at 0x7f748bbed4e0>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTToSemiLeptonic_PSweights/TTToSemiLeptonic_PSweights_forBDTtraining_central_58.root") at 0x7f748bbf10e0>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTToSemiLeptonic_PSweights/TTToSemiLeptonic_PSweights_forBDTtraining_central_59.root") at 0x7f74989536f0>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTToSemiLeptonic_PSweights/TTToSemiLeptonic_PSweights_forBDTtraining_central_6.root") at 0x7f7498957100>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTToSemiLeptonic_PSweights/TTToSemiLeptonic_PSweights_forBDTtraining_central_60.root") at 0x7f74989599c0>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTToSemiLeptonic_PSweights/TTToSemiLeptonic_PSweights_forBDTtraining_central_61.root") at 0x7f7498b05ef0>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTToSemiLeptonic_PSweights/TTToSemiLeptonic_PSweights_forBDTtraining_central_62.root") at 0x7f7498b08ee0>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTToSemiLeptonic_PSweights/TTToSemiLeptonic_PSweights_forBDTtraining_central_63.root") at 0x7f74773352d0>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTToSemiLeptonic_PSweights/TTToSemiLeptonic_PSweights_forBDTtraining_central_64.root") at 0x7f7477337ad0>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTToSemiLeptonic_PSweights/TTToSemiLeptonic_PSweights_forBDTtraining_central_65.root") at 0x7f74770168b0>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTToSemiLeptonic_PSweights/TTToSemiLeptonic_PSweights_forBDTtraining_central_66.root") at 0x7f747701a440>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTToSemiLeptonic_PSweights/TTToSemiLeptonic_PSweights_forBDTtraining_central_67.root") at 0x7f74ac548fc0>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTToSemiLeptonic_PSweights/TTToSemiLeptonic_PSweights_forBDTtraining_central_68.root") at 0x7f74ac54cb80>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTToSemiLeptonic_PSweights/TTToSemiLeptonic_PSweights_forBDTtraining_central_69.root") at 0x7f749ee37cc0>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTToSemiLeptonic_PSweights/TTToSemiLeptonic_PSweights_forBDTtraining_central_7.root") at 0x7f749ee3ba00>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTToSemiLeptonic_PSweights/TTToSemiLeptonic_PSweights_forBDTtraining_central_70.root") at 0x7f748f1e8860>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTToSemiLeptonic_PSweights/TTToSemiLeptonic_PSweights_forBDTtraining_central_71.root") at 0x7f748f1ec3f0>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTToSemiLeptonic_PSweights/TTToSemiLeptonic_PSweights_forBDTtraining_central_72.root") at 0x7f7478831660>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTToSemiLeptonic_PSweights/TTToSemiLeptonic_PSweights_forBDTtraining_central_73.root") at 0x7f7478835330>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTToSemiLeptonic_PSweights/TTToSemiLeptonic_PSweights_forBDTtraining_central_74.root") at 0x7f74ada5db70>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTToSemiLeptonic_PSweights/TTToSemiLeptonic_PSweights_forBDTtraining_central_75.root") at 0x7f74ada618d0>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTToSemiLeptonic_PSweights/TTToSemiLeptonic_PSweights_forBDTtraining_central_8.root") at 0x7f74aecda970>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTToSemiLeptonic_PSweights/TTToSemiLeptonic_PSweights_forBDTtraining_central_9.root") at 0x7f74aecde480>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTWJets_LO/TTWJets_LO_forBDTtraining_central_1.root") at 0x7f747a4f09b0>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTWJets_LO/TTWJets_LO_forBDTtraining_central_2.root") at 0x7f747a4f4480>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTWJets_LO/TTWJets_LO_forBDTtraining_central_3.root") at 0x7f747c1afe90>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTWJets_LO/TTWJets_LO_forBDTtraining_central_4.root") at 0x7f747c1b38a0>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTZJets_LO/TTZJets_LO_forBDTtraining_central_1.root") at 0x7f7496a6d330>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTZJets_LO/TTZJets_LO_forBDTtraining_central_2.root") at 0x7f7496a70ed0>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTZJets_LO/TTZJets_LO_forBDTtraining_central_3.root") at 0x7f7496a73700>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTZJets_LO/TTZJets_LO_forBDTtraining_central_4.root") at 0x7f74a1855fa0>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTZJets_LO/TTZJets_LO_forBDTtraining_central_5.root") at 0x7f74a18587f0>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTZJets_LO/TTZJets_LO_forBDTtraining_central_6.root") at 0x7f74951c4480>,
#  <ROOT.TFile object ("../root/2017/forBDTtraining/TTZJets_LO/TTZJets_LO_forBDTtraining_central_7.root") at 0x7f74951c6cd0>]

# %%
#=================A dictionary to contain all data
##the list is: ['signal',TTW','TTZ','TT']
if bkg == "TTV":
    myDict = {
    'signal':[],
    'TTW':[],
    'TTZ':[],
    #'TT':[]
    }
elif bkg == "TT":
    myDict = {
    'signal':[],
    #'TTW':[],
    #'TTZ':[],
    'TT':[]
    }
elif bkg == "all":
    myDict = {
    'signal':[],
    'TTW':[],
    'TTZ':[],
    'TT':[]
    }
myDict
# Out:
# {'TTW': [], 'TTZ': [], 'signal': []}

# %%
#====================Filling the dictionary
nEvtTot = 0
for categories in myDict.keys():
    try:
        print "\n\nEntering processes "+categories+"\nRoot files found in category: "
        for root_file in root_files:
            path_in = channel+"_"+forBDTtraining+"/sel/evtntuple/"+categories+"/evtTree"
            evt_tree=root_file.Get(path_in)
            if (evt_tree is not None) :
                if isinstance(evt_tree,ROOT.TTree):
                    print categories+"\t"+root_file.GetName()+' '+str(evt_tree.GetEntries())+' entries.'
                    myDict[categories].append(evt_tree)
                    nEvtTot += evt_tree.GetEntries()
            else:
                continue
    except:
        continue
myDict
# Out:
# Entering processes TTZ
# Root files found in category:
# TTZ	../root/2017/forBDTtraining/TTZJets_LO/TTZJets_LO_forBDTtraining_central_1.root 3309 entries.
# TTZ	../root/2017/forBDTtraining/TTZJets_LO/TTZJets_LO_forBDTtraining_central_2.root 3305 entries.
# TTZ	../root/2017/forBDTtraining/TTZJets_LO/TTZJets_LO_forBDTtraining_central_3.root 3238 entries.
# TTZ	../root/2017/forBDTtraining/TTZJets_LO/TTZJets_LO_forBDTtraining_central_4.root 3170 entries.
# TTZ	../root/2017/forBDTtraining/TTZJets_LO/TTZJets_LO_forBDTtraining_central_5.root 3317 entries.
# TTZ	../root/2017/forBDTtraining/TTZJets_LO/TTZJets_LO_forBDTtraining_central_6.root 3303 entries.
# TTZ	../root/2017/forBDTtraining/TTZJets_LO/TTZJets_LO_forBDTtraining_central_7.root 311 entries.
#
#
# Entering processes signal
# Root files found in category:
# signal	../root/2017/forBDTtraining/ttHToNonbb_M125_powheg/ttHToNonbb_M125_powheg_forBDTtraining_central_1.root 8593 entries.
# signal	../root/2017/forBDTtraining/ttHToNonbb_M125_powheg/ttHToNonbb_M125_powheg_forBDTtraining_central_2.root 8526 entries.
# signal	../root/2017/forBDTtraining/ttHToNonbb_M125_powheg/ttHToNonbb_M125_powheg_forBDTtraining_central_3.root 8650 entries.
# signal	../root/2017/forBDTtraining/ttHToNonbb_M125_powheg/ttHToNonbb_M125_powheg_forBDTtraining_central_4.root 8579 entries.
# signal	../root/2017/forBDTtraining/ttHToNonbb_M125_powheg/ttHToNonbb_M125_powheg_forBDTtraining_central_5.root 8509 entries.
# signal	../root/2017/forBDTtraining/ttHToNonbb_M125_powheg/ttHToNonbb_M125_powheg_forBDTtraining_central_6.root 1169 entries.
#
#
# Entering processes TTW
# Root files found in category:
# TTW	../root/2017/forBDTtraining/TTWJets_LO/TTWJets_LO_forBDTtraining_central_1.root 3141 entries.
# TTW	../root/2017/forBDTtraining/TTWJets_LO/TTWJets_LO_forBDTtraining_central_2.root 3081 entries.
# TTW	../root/2017/forBDTtraining/TTWJets_LO/TTWJets_LO_forBDTtraining_central_3.root 3185 entries.
# TTW	../root/2017/forBDTtraining/TTWJets_LO/TTWJets_LO_forBDTtraining_central_4.root 1592 entries.
# {'TTW': [<ROOT.TTree object ("evtTree") at 0x7f74aed5c6d0>,
#   <ROOT.TTree object ("evtTree") at 0x7f7477432f90>,
#   <ROOT.TTree object ("evtTree") at 0x7f74774320c0>,
#   <ROOT.TTree object ("evtTree") at 0x7f747902e6e0>,
#   <ROOT.TTree object ("evtTree") at 0x7f74aed5c6d0>,
#   <ROOT.TTree object ("evtTree") at 0x7f7477432f90>,
#   <ROOT.TTree object ("evtTree") at 0x7f74774320c0>,
#   <ROOT.TTree object ("evtTree") at 0x7f747902e6e0>],
#  'TTZ': [<ROOT.TTree object ("evtTree") at 0x7f73e4cce960>,
#   <ROOT.TTree object ("evtTree") at 0x7f73fb2cfc90>,
#   <ROOT.TTree object ("evtTree") at 0x7f7336a98ba0>,
#   <ROOT.TTree object ("evtTree") at 0x7f7336902700>,
#   <ROOT.TTree object ("evtTree") at 0x7f73365a4180>,
#   <ROOT.TTree object ("evtTree") at 0x7f7334814210>,
#   <ROOT.TTree object ("evtTree") at 0x7f7339cecdc0>,
#   <ROOT.TTree object ("evtTree") at 0x7f73e4cce960>,
#   <ROOT.TTree object ("evtTree") at 0x7f73fb2cfc90>,
#   <ROOT.TTree object ("evtTree") at 0x7f7336a98ba0>,
#   <ROOT.TTree object ("evtTree") at 0x7f7336902700>,
#   <ROOT.TTree object ("evtTree") at 0x7f73365a4180>,
#   <ROOT.TTree object ("evtTree") at 0x7f7334814210>,
#   <ROOT.TTree object ("evtTree") at 0x7f7339cecdc0>],
#  'signal': [<ROOT.TTree object ("evtTree") at 0x7f748b6392b0>,
#   <ROOT.TTree object ("evtTree") at 0x7f75029ba050>,
#   <ROOT.TTree object ("evtTree") at 0x7f749e2a6c90>,
#   <ROOT.TTree object ("evtTree") at 0x7f733a5fdb20>,
#   <ROOT.TTree object ("evtTree") at 0x7f733cb49700>,
#   <ROOT.TTree object ("evtTree") at 0x7f748bc0d5e0>,
#   <ROOT.TTree object ("evtTree") at 0x7f748b6392b0>,
#   <ROOT.TTree object ("evtTree") at 0x7f75029ba050>,
#   <ROOT.TTree object ("evtTree") at 0x7f749e2a6c90>,
#   <ROOT.TTree object ("evtTree") at 0x7f733a5fdb20>,
#   <ROOT.TTree object ("evtTree") at 0x7f733cb49700>,
#   <ROOT.TTree object ("evtTree") at 0x7f748bc0d5e0>]}

# %%
#======================Setting up TMVA and Loading Data

dataloader = TMVA.DataLoader('dataset')
for branch in myDict['signal'][0].GetListOfBranches():
    for selection in varlist:
        if (selection == branch.GetName()):
            try:
                dataloader.AddVariable(selection)
            except:
                print "\n\n\n\n\n\n\n"+selection+" has problems."

TMVA.Tools.Instance()
TMVA.PyMethodBase.PyInitialize()

output = TFile.Open('TMVA.root', 'RECREATE')
#dataloader.AddSignalTree(myDict['signal'][0], 1.0)


for categories in myDict.keys():
    if categories == 'signal': 
        for i in range(0,(len(myDict[categories]))):
            if myDict[categories][i].GetEntries()!=0:
                dataloader.AddSignalTree(myDict[categories][i], 1.0)
    else:
        for i in range(0,(len(myDict[categories]))):
            if myDict[categories][i].GetEntries()!=0:
                dataloader.AddBackgroundTree(myDict[categories][i], 1.0)
#train_sig = myDict["signal"][0].GetEntries()*frac
#print train_sig
#train_bkg = (nEvtTot - myDict["signal"][0].GetEntries())*frac
#print train_bkg
dataloader.PrepareTrainingAndTestTree(TCut(''),
                                      'nTrain_Signal=1000:nTrain_Background=1000:SplitMode=Random:NormMode=NumEvents:!V')
# Out:
# DataSetInfo              : [dataset] : Added class "Background"
#                          : Add Tree evtTree of type Background with 3309 events
#                          : Add Tree evtTree of type Background with 3305 events
#                          : Add Tree evtTree of type Background with 3238 events
#                          : Add Tree evtTree of type Background with 3170 events
#                          : Add Tree evtTree of type Background with 3317 events
#                          : Add Tree evtTree of type Background with 3303 events
#                          : Add Tree evtTree of type Background with 311 events
#                          : Add Tree evtTree of type Background with 3309 events
#                          : Add Tree evtTree of type Background with 3305 events
#                          : Add Tree evtTree of type Background with 3238 events
#                          : Add Tree evtTree of type Background with 3170 events
#                          : Add Tree evtTree of type Background with 3317 events
#                          : Add Tree evtTree of type Background with 3303 events
#                          : Add Tree evtTree of type Background with 311 events
# DataSetInfo              : [dataset] : Added class "Signal"
#                          : Add Tree evtTree of type Signal with 8593 events
#                          : Add Tree evtTree of type Signal with 8526 events
#                          : Add Tree evtTree of type Signal with 8650 events
#                          : Add Tree evtTree of type Signal with 8579 events
#                          : Add Tree evtTree of type Signal with 8509 events
#                          : Add Tree evtTree of type Signal with 1169 events
#                          : Add Tree evtTree of type Signal with 8593 events
#                          : Add Tree evtTree of type Signal with 8526 events
#                          : Add Tree evtTree of type Signal with 8650 events
#                          : Add Tree evtTree of type Signal with 8579 events
#                          : Add Tree evtTree of type Signal with 8509 events
#                          : Add Tree evtTree of type Signal with 1169 events
#                          : Add Tree evtTree of type Background with 3141 events
#                          : Add Tree evtTree of type Background with 3081 events
#                          : Add Tree evtTree of type Background with 3185 events
#                          : Add Tree evtTree of type Background with 1592 events
#                          : Add Tree evtTree of type Background with 3141 events
#                          : Add Tree evtTree of type Background with 3081 events
#                          : Add Tree evtTree of type Background with 3185 events
#                          : Add Tree evtTree of type Background with 1592 events
#                          : Dataset[dataset] : Class index : 0  name : Background
#                          : Dataset[dataset] : Class index : 1  name : Signal

# %%
# ==================================Book methods
factory = TMVA.Factory('TMVAClassification', output,
                       '!V:!Silent:Color:DrawProgressBar:AnalysisType=Classification')

# %%
####=============PyKeras 

#====================building the model
model = Sequential()
num_layers=100
num_nodes=100
model.add(Dense(num_nodes, activation='tanh', input_dim=len(varlist)-1))
for i in range(0,num_layers):
    model.add(Dense(num_nodes, activation='tanh'))
model.add(Dense(2, activation='relu'))
# ====================Set loss and optimizer
model.compile(loss='mean_squared_error',
              optimizer=keras.optimizers.Adam(lr=0.1, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False),
              metrics=['binary_accuracy', ])
# =====================Store model to file
model.save('model.h5')
model.summary()

factory.BookMethod(dataloader, TMVA.Types.kPyKeras, 'PyKeras','!H:!V:FilenameModel=model.h5:NumEpochs=100')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_817 (Dense)            (None, 100)               600
# _________________________________________________________________
# dense_818 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_819 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_820 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_821 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_822 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_823 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_824 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_825 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_826 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_827 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_828 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_829 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_830 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_831 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_832 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_833 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_834 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_835 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_836 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_837 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_838 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_839 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_840 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_841 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_842 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_843 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_844 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_845 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_846 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_847 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_848 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_849 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_850 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_851 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_852 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_853 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_854 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_855 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_856 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_857 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_858 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_859 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_860 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_861 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_862 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_863 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_864 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_865 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_866 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_867 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_868 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_869 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_870 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_871 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_872 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_873 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_874 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_875 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_876 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_877 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_878 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_879 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_880 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_881 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_882 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_883 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_884 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_885 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_886 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_887 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_888 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_889 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_890 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_891 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_892 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_893 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_894 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_895 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_896 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_897 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_898 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_899 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_900 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_901 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_902 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_903 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_904 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_905 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_906 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_907 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_908 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_909 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_910 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_911 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_912 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_913 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_914 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_915 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_916 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_917 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dense_918 (Dense)            (None, 2)                 202
# =================================================================
# Total params: 1,010,802
# Trainable params: 1,010,802
# Non-trainable params: 0
# _________________________________________________________________
# TypeErrorTraceback (most recent call last)
# <ipython-input-54-53e4e268c1fe> in <module>()
#      17 model.summary()
#      18
# ---> 19 factory.BookMethod(dataloader, TMVA.Types.kPyKeras, 'PyKeras','!H:!V:FilenameModel=model.h5:NumEpochs=100')
#      20
#
# TypeError: none of the 3 overloaded methods succeeded. Full details:
#   TMVA::MethodBase* TMVA::Factory::BookMethod(TMVA::DataLoader* loader, TString theMethodName, TString methodTitle, TString theOption = "") =>
#     could not convert argument 2
#   TMVA::MethodBase* TMVA::Factory::BookMethod(TMVA::DataLoader* loader, TMVA::Types::EMVA theMethod, TString methodTitle, TString theOption = "") =>
#     FATAL error (C++ exception of type runtime_error)
#   TMVA::MethodBase* TMVA::Factory::BookMethod(TMVA::DataLoader*, TMVA::Types::EMVA, TString, TString, TMVA::Types::EMVA, TString) =>
#     takes at least 6 arguments (4 given)
# <FATAL>                         : Booking failed since method with title <PyKeras> already exists in with DataSet Name <dataset>  Booking failed since method with title <PyKeras> already exists in with DataSet Name <dataset>  Booking failed since method with title <PyKeras> already exists in with DataSet Name <dataset>
# ***> abort program execution
# <FATAL>                         : Booking failed since method with title <PyKeras> already exists in with DataSet Name <dataset>  Booking failed since method with title <PyKeras> already exists in with DataSet Name <dataset>  Booking failed since method with title <PyKeras> already exists in with DataSet Name <dataset>  Booking failed since method with title <PyKeras> already exists in with DataSet Name <dataset>
# ***> abort program execution

# %%
factory.TrainAllMethods()
# Out:
# __main__:1: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
# ValueErrorTraceback (most recent call last)
# <string> in <module>()
#
# /home/rajat/.local/lib/python2.7/site-packages/keras/engine/training.pyc in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#     948             sample_weight=sample_weight,
#     949             class_weight=class_weight,
# --> 950             batch_size=batch_size)
#     951         # Prepare validation data.
#     952         do_validation = False
#
# /home/rajat/.local/lib/python2.7/site-packages/keras/engine/training.pyc in _standardize_user_data(self, x, y, sample_weight, class_weight, check_array_lengths, batch_size)
#     747             feed_input_shapes,
#     748             check_batch_axis=False,  # Don't enforce the batch size.
# --> 749             exception_prefix='input')
#     750
#     751         if y is not None:
#
# /home/rajat/.local/lib/python2.7/site-packages/keras/engine/training_utils.pyc in standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     135                             ': expected ' + names[i] + ' to have shape ' +
#     136                             str(shape) + ' but got array with shape ' +
# --> 137                             str(data_shape))
#     138     return data
#     139
#
# ValueError: Error when checking input: expected dense_613_input to have shape (6,) but got array with shape (5,)
# ExceptionTraceback (most recent call last)
# <ipython-input-55-4bb1800441f7> in <module>()
# ----> 1 factory.TrainAllMethods()
#
# Exception: void TMVA::Factory::TrainAllMethods() =>
#     FATAL error (C++ exception of type runtime_error)
# Factory                  : Booking failed since method with title <PyKeras> already exists in with DataSet Name <dataset>  Booking failed since method with title <PyKeras> already exists in with DataSet Name <dataset>  Booking failed since method with title <PyKeras> already exists in with DataSet Name <dataset>  Booking failed since method with title <PyKeras> already exists in with DataSet Name <dataset>  Train all methods
# Factory                  : Train method: PyKeras for Classification
#                          :
#                          : Option SaveBestOnly: Only model weights with smallest validation loss will be stored
# <WARNING>                : Failed to run python code: history = model.fit(trainX, trainY, sample_weight=trainWeights, batch_size=batchSize, nb_epoch=numEpochs, verbose=verbose, validation_data=(valX, valY, valWeights), callbacks=callbacks)
# <WARNING>                : Python error message:
# <FATAL>                         : Failed to train model
# ***> abort program execution
